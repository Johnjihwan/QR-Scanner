# %%
import pyzbar.pyzbar as pyzbar
import cv2
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
Image("img/QRCodeImg.jpg")

# %%
img = cv2.imread("img/QRCodeImg.jpg")
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
decoded = pyzbar.decode(gray)

decoded
# Out:
# [Decoded(data=b'http://m.site.naver.com/0KoUO', type='QRCODE', rect=Rect(left=76, top=76, width=204, height=204), polygon=[Point(x=76, y=76), Point(x=76, y=280), Point(x=280, y=280), Point(x=280, y=76)])]

# %%
for d in decoded:
    print(d.data.decode('utf-8'))
    print(d.type)
    
    cv2.rectangle(img, (d.rect[0], d.rect[1]), (d.rect[0] + d.rect[2], d.rect[1] + d.rect[3]), (0, 0, 255), 2)
    
plt.imshow(img)
# Out:
# http://m.site.naver.com/0KoUO
# QRCODE
